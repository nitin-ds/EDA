# %%
import pandas as pd
import io
import requests
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/heart/heart.dat"
s = requests.get(url).content
s = s.decode('utf-8')
s_rows = s.split('\n')

# %%
s_rows = s.split('\n')
s_rows_cols = [each.split() for each in s_rows]
header_row = ['age','sex','chestpain','restBP','chol','sugar','ecg','maxhr','angina','dep','exercise','fluor','thal','diagnosis']
c = pd.DataFrame(s_rows_cols, columns = header_row)
c.head()
# Out:
#     age  sex chestpain restBP   chol sugar  ecg  maxhr angina  dep exercise  \
# 0  70.0  1.0       4.0  130.0  322.0   0.0  2.0  109.0    0.0  2.4      2.0
# 1  67.0  0.0       3.0  115.0  564.0   0.0  2.0  160.0    0.0  1.6      2.0
# 2  57.0  1.0       2.0  124.0  261.0   0.0  0.0  141.0    0.0  0.3      1.0
# 3  64.0  1.0       4.0  128.0  263.0   0.0  0.0  105.0    1.0  0.2      2.0
# 4  74.0  0.0       2.0  120.0  269.0   0.0  2.0  121.0    1.0  0.2      1.0
#
#   fluor thal diagnosis
# 0   3.0  3.0         2
# 1   0.0  7.0         1
# 2   0.0  7.0         2
# 3   1.0  7.0         1
# 4   1.0  3.0         1
